# %%
import numpy as np
import matplotlib.pyplot as plt
from func import GuessPlayer
from tensorflow.keras.preprocessing import image
from tensorflow import keras
model = keras.models.load_model('FinalModel.h5')

# %%
img = image.load_img("which player 1.jpg"
                    ,target_size = (100,100))
plt.imshow(img)
test_img = np.asarray(img)
#print(test_img.shape)
# reshape to add 1 row
test_img = test_img.reshape(1,100,100,3)
#print(test_img.shape)
yhat = model.predict(test_img)
GuessPlayer(yhat)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 'SURYAKUMAR YADAV'
